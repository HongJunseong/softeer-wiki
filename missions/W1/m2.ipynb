# %%
import sqlite3

# connect to the database
conn = sqlite3.connect('northwind.db')
cursor = conn.cursor()

# %%
cursor.execute("DROP TABLE IF EXISTS Customers")

cursor.execute("""
CREATE TABLE IF NOT EXISTS Customers (
    CustomerID INTEGER PRIMARY KEY,
    CustomerName TEXT,
    ContactName TEXT,
    Address TEXT,
    City TEXT,
    PostalCode TEXT,
    Country TEXT
)
""")

conn.commit()

# %%
cursor.execute('INSERT INTO Customers (CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country) VALUES (?, ?, ?, ?, ?, ?, ?)',
               (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
               )

cursor.execute('INSERT INTO Customers (CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country) VALUES (?, ?, ?, ?, ?, ?, ?)',
               (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
               )

cursor.execute('INSERT INTO Customers (CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country) VALUES (?, ?, ?, ?, ?, ?, ?)',
               (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
               )

cursor.execute('INSERT INTO Customers (CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country) VALUES (?, ?, ?, ?, ?, ?, ?)',
               (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
               )

cursor.execute('INSERT INTO Customers (CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country) VALUES (?, ?, ?, ?, ?, ?, ?)',
               (5, 'Berglunds snabbköp', 'Christina Berglund',  'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')
)

conn.commit()

# %%
cursor.execute('SELECT * FROM Customers')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')

# %%
cursor.execute('SELECT CustomerName, City FROM Customers')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Alfreds Futterkiste', 'Berlin')
# ('Ana Trujillo Emparedados y helados', 'México D.F.')
# ('Antonio Moreno Taquería', 'México D.F.')
# ('Around the Horn', 'London')
# ('Berglunds snabbköp', 'Luleå')

# %%
cursor.execute('SELECT DISTINCT Country FROM Customers')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Germany',)
# ('Mexico',)
# ('UK',)
# ('Sweden',)

# %%
cursor.execute('SELECT Country FROM Customers')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Germany',)
# ('Mexico',)
# ('Mexico',)
# ('UK',)
# ('Sweden',)

# %%
cursor.execute('SELECT COUNT(DISTINCT Country) FROM Customers')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (4,)

# %%
cursor.execute('SELECT COUNT(*) AS DistinctCountries FROM (SELECT DISTINCT Country FROM Customers)')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (4,)

# %%
cursor.execute('SELECT * FROM Customers WHERE Country = "Mexico"')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')

# %%
cursor.execute('SELECT * FROM Customers WHERE CustomerID = 1')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')

# %%
cursor.execute('SELECT * FROM Customers WHERE CustomerID > 80')
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
# remove the Products table if it exists
cursor.execute("DROP TABLE IF EXISTS Products")

cursor.execute("""
CREATE TABLE IF NOT EXISTS Products (
    ProductID INTEGER PRIMARY KEY,
    ProductName TEXT,
    SupplierID INTEGER,
    CategoryID INTEGER,
    Unit TEXT,
    Price REAL
)
""")

conn.commit()

# %%
cursor.execute('INSERT INTO Products (ProductID, ProductName, SupplierID, CategoryID, Unit, Price) VALUES (?, ?, ?, ?, ?, ?)',
               (1, 'Chais', 1, 1, '10 boxes x 20 bags', 18.0)
               )

cursor.execute('INSERT INTO Products (ProductID, ProductName, SupplierID, CategoryID, Unit, Price) VALUES (?, ?, ?, ?, ?, ?)',
               (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.0)
               )

cursor.execute('INSERT INTO Products (ProductID, ProductName, SupplierID, CategoryID, Unit, Price) VALUES (?, ?, ?, ?, ?, ?)',
               (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.0)
               )

cursor.execute('INSERT INTO Products (ProductID, ProductName, SupplierID, CategoryID, Unit, Price) VALUES (?, ?, ?, ?, ?, ?)',
               (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22.0)
               )

cursor.execute('INSERT INTO Products (ProductID, ProductName, SupplierID, CategoryID, Unit, Price) VALUES (?, ?, ?, ?, ?, ?)',
               (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35)
            )

conn.commit()

# %%
cursor.execute('SELECT * FROM Products ORDER BY ProductName DESC')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35)
# (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22.0)
# (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.0)
# (1, 'Chais', 1, 1, '10 boxes x 20 bags', 18.0)
# (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.0)

# %%
cursor.execute('SELECT * FROM Customers ORDER BY Country, CustomerName')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')

# %%
cursor.execute('SELECT * FROM Customers ORDER BY Country ASC, CustomerName DESC')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')

# %%
cursor.execute('SELECT * FROM Customers WHERE Country = "Spain" AND CustomerName LIKE "G%"')
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute('SELECT * FROM Customers WHERE Country = "Brazil" AND City = "Rio de Janeiro" AND CustomerID > 50')
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute('SELECT * FROM Customers WHERE Country = "Spain" AND (CustomerName LIKE "G%" OR CustomerName LIKE "R%")')
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute('SELECT * FROM Customers WHERE Country = "Spain" AND CustomerName LIKE "G%" OR CustomerName LIKE "R%"')
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute('SELECT * FROM Customers WHERE NOT Country = "Spain"')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')

# %%
cursor.execute('''
    SELECT * FROM Customers
    WHERE City NOT IN ('Paris', 'London')
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')

# %%
cursor.execute('''
    SELECT * FROM Customers
    WHERE NOT CustomerID > 50
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')

# %%
cursor.execute('''
    SELECT * FROM Customers
    WHERE NOT CustomerId < 50
''')
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute('''
    INSERT INTO Customers (CustomerName, ContactName, Address, City, PostalCode, Country)
    VALUES
    ('Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway'),
    ('Greasy Burger', 'Per Olsen', 'Gateveien 15', 'Sandnes', '4306', 'Norway'),
    ('Tasty Tee', 'Finn Egan', 'Streetroad 19B', 'Liverpool', 'L1 0AA', 'UK')
''')

# %%
cursor.execute('''
    SELECT * FROM Customers
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')
# (6, 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway')
# (7, 'Greasy Burger', 'Per Olsen', 'Gateveien 15', 'Sandnes', '4306', 'Norway')
# (8, 'Tasty Tee', 'Finn Egan', 'Streetroad 19B', 'Liverpool', 'L1 0AA', 'UK')

# %%
cursor.execute('''
    SELECT CustomerName, ContactName, Address
    FROM Customers
    WHERE Address IS NOT NULL
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57')
# ('Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222')
# ('Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312')
# ('Around the Horn', 'Thomas Hardy', '120 Hanover Sq.')
# ('Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8')
# ('Cardinal', 'Tom B. Erichsen', 'Skagen 21')
# ('Greasy Burger', 'Per Olsen', 'Gateveien 15')
# ('Tasty Tee', 'Finn Egan', 'Streetroad 19B')

# %%
cursor.execute('''
    UPDATE Customers
    SET ContactName = 'Alfred Schmidt', City= 'Frankfurt'
    WHERE CustomerID = 1
''')

# %%
cursor.execute('''
    SELECT * FROM Customers
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Alfred Schmidt', 'Obere Str. 57', 'Frankfurt', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')
# (6, 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway')
# (7, 'Greasy Burger', 'Per Olsen', 'Gateveien 15', 'Sandnes', '4306', 'Norway')
# (8, 'Tasty Tee', 'Finn Egan', 'Streetroad 19B', 'Liverpool', 'L1 0AA', 'UK')

# %%
cursor.execute('''
    UPDATE Customers
    SET ContactName='Juan'
    WHERE Country='Mexico'
''')

# %%
cursor.execute('''
    SELECT * FROM Customers
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Alfred Schmidt', 'Obere Str. 57', 'Frankfurt', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Juan', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Juan', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')
# (6, 'Cardinal', 'Tom B. Erichsen', 'Skagen 21', 'Stavanger', '4006', 'Norway')
# (7, 'Greasy Burger', 'Per Olsen', 'Gateveien 15', 'Sandnes', '4306', 'Norway')
# (8, 'Tasty Tee', 'Finn Egan', 'Streetroad 19B', 'Liverpool', 'L1 0AA', 'UK')

# %%
cursor.execute('''
    UPDATE Customers
    SET ContactName='Juan'
''')

# %%
cursor.execute('''
    SELECT * FROM Customers
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Juan', 'Obere Str. 57', 'Frankfurt', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Juan', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Juan', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (4, 'Around the Horn', 'Juan', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# (5, 'Berglunds snabbköp', 'Juan', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')
# (6, 'Cardinal', 'Juan', 'Skagen 21', 'Stavanger', '4006', 'Norway')
# (7, 'Greasy Burger', 'Juan', 'Gateveien 15', 'Sandnes', '4306', 'Norway')
# (8, 'Tasty Tee', 'Juan', 'Streetroad 19B', 'Liverpool', 'L1 0AA', 'UK')

# %%
cursor.execute('''
    DELETE FROM Customers WHERE CustomerName='Alfreds Futterkiste'
''')
conn.commit()

# %%
cursor.execute('''
    SELECT * FROM Customers
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (2, 'Ana Trujillo Emparedados y helados', 'Juan', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Juan', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (4, 'Around the Horn', 'Juan', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# (5, 'Berglunds snabbköp', 'Juan', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')
# (6, 'Cardinal', 'Juan', 'Skagen 21', 'Stavanger', '4006', 'Norway')
# (7, 'Greasy Burger', 'Juan', 'Gateveien 15', 'Sandnes', '4306', 'Norway')
# (8, 'Tasty Tee', 'Juan', 'Streetroad 19B', 'Liverpool', 'L1 0AA', 'UK')

# %%
cursor.execute('''
    DELETE FROM Customers;
''')
conn.commit()

# %%
cursor.execute('''
    DROP TABLE Customers;
''')

conn.commit()

# %%
# remove the Customers table if it exists
cursor.execute("DROP TABLE IF EXISTS Customers")

cursor.execute("""
CREATE TABLE IF NOT EXISTS Customers (
    CustomerID INTEGER PRIMARY KEY,
    CustomerName TEXT,
    ContactName TEXT,
    Address TEXT,
    City TEXT,
    PostalCode TEXT,
    Country TEXT
)
""")

conn.commit()

# %%
cursor.execute('INSERT INTO Customers (CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country) VALUES (?, ?, ?, ?, ?, ?, ?)',
               (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
               )

cursor.execute('INSERT INTO Customers (CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country) VALUES (?, ?, ?, ?, ?, ?, ?)',
               (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
               )

cursor.execute('INSERT INTO Customers (CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country) VALUES (?, ?, ?, ?, ?, ?, ?)',
               (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
               )

cursor.execute('INSERT INTO Customers (CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country) VALUES (?, ?, ?, ?, ?, ?, ?)',
               (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
               )

cursor.execute('INSERT INTO Customers (CustomerID, CustomerName, ContactName, Address, City, PostalCode, Country) VALUES (?, ?, ?, ?, ?, ?, ?)',
               (5, 'Berglunds snabbköp', 'Christina Berglund',  'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')
)

conn.commit()

# %%
cursor.execute('''
    SELECT * FROM Customers
    LIMIT 3;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')

# %%
cursor.execute('''
    SELECT * FROM Customers
    WHERE Country = 'Germany'
    LIMIT 3;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')

# %%
cursor.execute('''
    SELECT * FROM Customers
    ORDER BY CustomerName DESC
    LIMIT 3;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')

# %%
cursor.execute('''
    SELECT MIN(Price)
    FROM Products;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (10.0,)

# %%
cursor.execute('''
    SELECT MIN(Price) AS SmallestPrice
    FROM Products;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (10.0,)

# %%
# remove the Employees table if it exists
cursor.execute("DROP TABLE IF EXISTS Employees")

cursor.execute("""
CREATE TABLE IF NOT EXISTS Employees (
    EmployeeID INTEGER PRIMARY KEY,
    LastName TEXT,
    FirstName TEXT,
    BirthDate DATE,
    Photo TEXT,
    Notes TEXT
)
""")

conn.commit()

# %%
cursor.execute('''
                   INSERT INTO Employees (EmployeeID, LastName, FirstName, BirthDate, Photo, Notes)
                   VALUES
                   (1, 'Davolio', 'Nancy', '1968-12-08', 'EmpID1.pic', 'Education includes a BA in psychology from Colorado State University. She also completed (The Art of the Cold Call). Nancy is a member of the Sales Club.'),
                   (2, 'Fuller', 'Andrew', '1952-02-19', 'EmpID2.pic', 'Andrew received his BTS commercial and a Ph.D. in international marketing from the University of Dallas. He is fluent in French and Italian and reads German. He joined the company as a sales representative, was promoted to sales manager and was then named vice president of sales. Andrew is a member of the Sales Club.'),
                   (3, 'Leverling', 'Janet', '1963-08-30', 'EmpID3.pic', 'Janet has a BS degree in chemistry from Boston College. She also completed (The Art of the Cold Call). Janet is a member of the Sales Club.'),
                   (4, 'Peacock', 'Margaret', '1937-09-19', 'EmpID4.pic', 'Margaret holds a BA in English literature from Concordia College (1958) and an MA from the American Institute of Culinary Arts (1966). She was assigned to the London office temporarily from July through November 1992.'),
                   (5, 'Buchanan', 'Steven', '1955-03-04', 'EmpID5.pic', 'Steven Buchanan graduated from St. Andrews University, Scotland, with a BSC degree in 1976. Upon joining the company as a sales representative in 1992, he spent 6 months in an orientation program at the Seattle office and then returned to his permanent post in London. He was promoted to sales manager in March 1993. Mr. Buchanan has completed the courses "Successful Telemarketing" and "International Sales Management." He is fluent in French.')
                   '''
)

conn.commit()

# %%
cursor.execute('''
    SELECT MIN(BirthDate) AS EarliestBirthdate
    FROM Employees;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('1937-09-19',)

# %%
cursor.execute('''
    SELECT MIN(Price) AS SmallestPrice, CategoryID
    FROM Products
    GROUP BY CategoryID;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (18.0, 1)
# (10.0, 2)

# %%
cursor.execute('''
    SELECT MAX(BirthDate) AS LatestBirthdate
    FROM Employees;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('1968-12-08',)

# %%
cursor.execute('''
    SELECT MAX(Price)
    FROM Products;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (22.0,)

# %%
cursor.execute('''
    SELECT MAX(Price) AS HighestPrice
    FROM Products;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (22.0,)

# %%
cursor.execute('''
    SELECT MAX(Price) AS HighestPrice, CategoryID
    FROM Products
    GROUP BY CategoryID;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (19.0, 1)
# (22.0, 2)

# %%
cursor.execute('''
    SELECT COUNT(*)
    FROM Products;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (5,)

# %%
cursor.execute('''
    SELECT COUNT(ProductName)
    FROM Products;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (5,)

# %%
cursor.execute('''
    SELECT COUNT(DISTINCT Price)
    FROM Products;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (5,)

# %%
cursor.execute('''
    SELECT COUNT(ProductID)
    FROM Products
    WHERE Price > 20;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (2,)

# %%
cursor.execute('''
    SELECT COUNT(*) AS [Number of records]
    FROM Products;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (5,)

# %%
cursor.execute('''
    SELECT COUNT(*) AS [Number of records], CategoryID
    FROM Products
    GROUP BY CategoryID;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (2, 1)
# (3, 2)

# %%
# remove the OrderDetails table if it exists
cursor.execute("DROP TABLE IF EXISTS OrderDetails")

cursor.execute("""
CREATE TABLE IF NOT EXISTS OrderDetails (
    OrderDetailID INTEGER PRIMARY KEY,
    OrderID INTEGER,
    ProductID INTEGER,
    Quantity INTEGER
)
""")

conn.commit()

# %%
cursor.execute('''
                   INSERT INTO OrderDetails (OrderDetailID, OrderID, ProductID, Quantity)
                   VALUES
                   (1, 10248, 11, 12),
                   (2, 10248, 42, 10),
                   (3, 10248, 72, 5),
                   (4, 10249, 14, 9),
                   (5, 10249, 51, 40)
                   '''
)

conn.commit()

# %%
cursor.execute('''
    SELECT SUM(Quantity)
    FROM OrderDetails;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (76,)

# %%
cursor.execute('''
    SELECT SUM(Quantity)
    FROM OrderDetails
    WHERE ProductId = 11;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (12,)

# %%
cursor.execute('''
    SELECT SUM(Quantity) AS total
    FROM OrderDetails;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (76,)

# %%
cursor.execute('''
    SELECT OrderID, SUM(Quantity) AS [Total Quantity]
    FROM OrderDetails
    GROUP BY OrderID;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (10248, 27)
# (10249, 49)

# %%
cursor.execute('''
    SELECT SUM(Quantity * 10)
    FROM OrderDetails;
''')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (760,)

# %%
cursor.execute("ATTACH DATABASE 'products.db' AS prod")

# %%
cursor.execute("""
    SELECT SUM(p.Price * od.Quantity)
    FROM Orderdetails AS od
    LEFT JOIN prod.Products AS p
        ON od.ProductID = p.ProductID;

""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (None,)

# %%
cursor.execute("""
    SELECT AVG(Price)
    FROM Products;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (18.07,)

# %%
cursor.execute("""
    SELECT AVG(Price)
    FROM Products
    WHERE CategoryID = 1;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (18.5,)

# %%
cursor.execute("""
    SELECT AVG(Price) AS [average price]
    FROM Products;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (18.07,)

# %%
cursor.execute("""
    SELECT * FROM Products
    WHERE Price > (SELECT AVG(Price) FROM Products);
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.0)
# (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22.0)
# (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35)

# %%
cursor.execute("""
    SELECT AVG(Price) AS AveragePrice, CategoryID
    FROM Products
    GROUP BY CategoryID;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (18.5, 1)
# (17.783333333333335, 2)

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE CustomerName LIKE 'a%';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE city LIKE '%on%';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE city LIKE 'l_nd__';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE CustomerName LIKE 'La%';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE CustomerName LIKE 'a%' OR CustomerName LIKE 'b%';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE CustomerName LIKE '%a';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE CustomerName LIKE 'b%s';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE CustomerName LIKE '%or%';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE CustomerName LIKE 'a__%';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE CustomerName LIKE '_r%';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE Country LIKE 'Spain';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE CustomerName LIKE '%es';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE CustomerName LIKE '%mer%';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE City LIKE '_ondon';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE City LIKE 'L___on';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE CustomerName LIKE '[bsp]%';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE CustomerName LIKE '[a-f]%';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE CustomerName LIKE 'a__%';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE CustomerName LIKE '_r%';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE Country IN ('Germany', 'France', 'UK');
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE Country = 'Germany' OR Country = 'France' OR Country = 'UK';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')

# %%
cursor.execute("""
    SELECT * FROM Customers
    WHERE Country NOT IN ('Germany', 'France', 'UK');
    """)
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')

# %%
cursor.execute("""
    SELECT * FROM Products
    WHERE Price BETWEEN 10 AND 20;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Chais', 1, 1, '10 boxes x 20 bags', 18.0)
# (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.0)
# (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.0)

# %%
cursor.execute("""
    SELECT * FROM Products
    WHERE Price NOT BETWEEN 10 AND 20;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22.0)
# (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35)

# %%
cursor.execute("""
    SELECT * FROM Products
    WHERE Price BETWEEN 10 AND 20
    AND CategoryID IN (1,2,3);
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Chais', 1, 1, '10 boxes x 20 bags', 18.0)
# (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.0)
# (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.0)

# %%
cursor.execute("""
    SELECT * FROM Products
    WHERE ProductName BETWEEN 'Geitost' AND 'Louisiana Hot Spiced Okra'
    ORDER BY ProductName;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute("""
    SELECT * FROM Products
    WHERE ProductName NOT BETWEEN 'Geitost' AND 'Louisiana Hot Spiced Okra'
    ORDER BY ProductName;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.0)
# (1, 'Chais', 1, 1, '10 boxes x 20 bags', 18.0)
# (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.0)
# (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22.0)
# (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35)

# %%
# remove the Order table if it exists
cursor.execute("DROP TABLE IF EXISTS Orders")

cursor.execute("""
CREATE TABLE IF NOT EXISTS Orders (
    OrderID INTEGER PRIMARY KEY,
    CustomerID INTEGER,
    EmployeeID INTEGER,
    OrderDate DATE,
    ShipperID INTEGER
)
""")

conn.commit()

# %%
cursor.execute('''
                   INSERT INTO Orders (OrderID, CustomerID, EmployeeID, OrderDate, ShipperID)
                   VALUES
                   (10248, 90, 5,'1996-07-04', 3),
                   (10249, 81, 6,'1996-07-05', 1),
                   (10250, 34, 7,'1996-07-08', 2),
                   (10251, 67, 8,'1996-07-08', 1),
                   (10252, 45, 9,'1996-07-09', 4)
                   '''
)

conn.commit()

# %%
cursor.execute("""
    SELECT * FROM Orders
    WHERE OrderDate BETWEEN '1996-07-01' AND '1996-07-31';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (10248, 90, 5, '1996-07-04', 3)
# (10249, 81, 6, '1996-07-05', 1)
# (10250, 34, 7, '1996-07-08', 2)
# (10251, 67, 8, '1996-07-08', 1)
# (10252, 45, 9, '1996-07-09', 4)

# %%
cursor.execute("""
    SELECT CustomerID AS ID, CustomerName AS Customer
    FROM Customers;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste')
# (2, 'Ana Trujillo Emparedados y helados')
# (3, 'Antonio Moreno Taquería')
# (4, 'Around the Horn')
# (5, 'Berglunds snabbköp')

# %%
cursor.execute("""
    SELECT ProductName AS [My Great Products]
    FROM Products;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Chais',)
# ('Chang',)
# ('Aniseed Syrup',)
# ("Chef Anton's Cajun Seasoning",)
# ("Chef Anton's Gumbo Mix",)

# %%
cursor.execute("""
    SELECT ProductName AS "My Great Products"
    FROM Products;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Chais',)
# ('Chang',)
# ('Aniseed Syrup',)
# ("Chef Anton's Cajun Seasoning",)
# ("Chef Anton's Gumbo Mix",)

# %%
cursor.execute("""
    SELECT CustomerName, Address + ', ' + PostalCode + ' ' + City + ', ' + Country AS Address
    FROM Customers;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Alfreds Futterkiste', 12209)
# ('Ana Trujillo Emparedados y helados', 5021)
# ('Antonio Moreno Taquería', 5023)
# ('Around the Horn', 120)
# ('Berglunds snabbköp', 0)

# %%
cursor.execute("""
    SELECT CustomerName, CONCAT(Address,', ',PostalCode,', ',City,', ',Country) AS Address
    FROM Customers;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Alfreds Futterkiste', 'Obere Str. 57, 12209, Berlin, Germany')
# ('Ana Trujillo Emparedados y helados', 'Avda. de la Constitución 2222, 05021, México D.F., Mexico')
# ('Antonio Moreno Taquería', 'Mataderos 2312, 05023, México D.F., Mexico')
# ('Around the Horn', '120 Hanover Sq., WA1 1DP, London, UK')
# ('Berglunds snabbköp', 'Berguvsvägen 8, S-958 22, Luleå, Sweden')

# %%
cursor.execute("""
    SELECT * FROM Customers AS Persons;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')

# %%
cursor.execute("ATTACH DATABASE 'orders.db' AS ord")

# %%
cursor.execute("""
    SELECT c.CustomerName, o.OrderID
    FROM Customers AS c
    JOIN ord.Orders AS o
    ON c.CustomerID = o.CustomerID;
""")

rows = cursor.fetchall()

for row in rows:

    print(row)

# %%
cursor.execute("""
    SELECT Orders.OrderID, Customers.CustomerName, Orders.OrderDate
    FROM Orders
    INNER JOIN Customers ON Orders.CustomerID=Customers.CustomerID;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
# remove the Categories table if it exists
cursor.execute("DROP TABLE IF EXISTS Categories")

# create the Categories table
cursor.execute("""
CREATE TABLE Categories (
    CategoryID INTEGER PRIMARY KEY,
    CategoryName TEXT,
    Description TEXT
)
""")

# %%
cursor.execute("""
INSERT INTO Categories (CategoryID, CategoryName, Description)
VALUES (?, ?, ?)
""", (
    2,
    'Condiments',
    'Sweet and savory sauces, relishes, spreads, and seasonings'
))

conn.commit()

# %%
cursor.execute("""
    SELECT ProductID, ProductName, CategoryName
    FROM Products
    INNER JOIN Categories ON Products.CategoryID = Categories.CategoryID;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (3, 'Aniseed Syrup', 'Condiments')
# (4, "Chef Anton's Cajun Seasoning", 'Condiments')
# (5, "Chef Anton's Gumbo Mix", 'Condiments')

# %%
cursor.execute("""
    SELECT Products.ProductID, Products.ProductName, Categories.CategoryName
    FROM Products
    JOIN Categories ON Products.CategoryID = Categories.CategoryID;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (3, 'Aniseed Syrup', 'Condiments')
# (4, "Chef Anton's Cajun Seasoning", 'Condiments')
# (5, "Chef Anton's Gumbo Mix", 'Condiments')

# %%
# remove the Shippers table if it exists
cursor.execute("DROP TABLE IF EXISTS Shippers")

# create the Shippers table
cursor.execute("""
CREATE TABLE Shippers (
    ShipperID INTEGER PRIMARY KEY,
    ShipperName TEXT,
    Phone TEXT
)
""")

# %%
cursor.executemany("""
INSERT INTO Shippers (ShipperID, ShipperName, Phone)
VALUES (?, ?, ?)
""", [
    (1, "Speedy Express", "(503) 555-9831"),
    (2, "United Package", "(503) 555-3199"),
    (3, "Federal Shipping", "(503) 555-9931")
])

conn.commit()

# %%
cursor.execute("""
    SELECT Orders.OrderID, Customers.CustomerName, Shippers.ShipperName
    FROM Orders
    INNER JOIN Customers ON Orders.CustomerID = Customers.CustomerID
    INNER JOIN Shippers ON Orders.ShipperID = Shippers.ShipperID;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute("""
    SELECT Customers.CustomerName, Orders.OrderID
    FROM Customers
    LEFT JOIN Orders ON Customers.CustomerID = Orders.CustomerID
    ORDER BY Customers.CustomerName;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Alfreds Futterkiste', None)
# ('Ana Trujillo Emparedados y helados', None)
# ('Antonio Moreno Taquería', None)
# ('Around the Horn', None)
# ('Berglunds snabbköp', None)

# %%
cursor.execute("""
    SELECT Customers.CustomerName, Orders.OrderID
    FROM Customers
    LEFT JOIN Orders
    ON Customers.CustomerID = Orders.CustomerID
    WHERE Orders.CustomerID IS NULL;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Alfreds Futterkiste', None)
# ('Ana Trujillo Emparedados y helados', None)
# ('Antonio Moreno Taquería', None)
# ('Around the Horn', None)
# ('Berglunds snabbköp', None)

# %%
cursor.execute("""
    SELECT Orders.OrderID, Employees.LastName, Employees.FirstName
    FROM Orders
    RIGHT JOIN Employees ON Orders.EmployeeID = Employees.EmployeeID
    ORDER BY Orders.OrderID;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (None, 'Davolio', 'Nancy')
# (None, 'Fuller', 'Andrew')
# (None, 'Leverling', 'Janet')
# (None, 'Peacock', 'Margaret')
# (10248, 'Buchanan', 'Steven')

# %%
cursor.execute("""
    SELECT Customers.CustomerName, Orders.OrderID
    FROM Customers
    FULL JOIN Orders
    ON Customers.CustomerID = Orders.CustomerID;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Alfreds Futterkiste', None)
# ('Ana Trujillo Emparedados y helados', None)
# ('Antonio Moreno Taquería', None)
# ('Around the Horn', None)
# ('Berglunds snabbköp', None)
# (None, 10248)
# (None, 10249)
# (None, 10250)
# (None, 10251)
# (None, 10252)

# %%
cursor.execute("""
    SELECT A.CustomerName AS CustomerName1, B.CustomerName AS CustomerName2, A.City
    FROM Customers A, Customers B
    WHERE A.CustomerID <> B.CustomerID
    AND A.City = B.City
    ORDER BY A.City;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Ana Trujillo Emparedados y helados', 'Antonio Moreno Taquería', 'México D.F.')
# ('Antonio Moreno Taquería', 'Ana Trujillo Emparedados y helados', 'México D.F.')

# %%
# remove the Suppliers table if it exists
cursor.execute("DROP TABLE IF EXISTS Suppliers")

# create the Suppliers table
cursor.execute("""
CREATE TABLE Suppliers (
    SupplierID INTEGER PRIMARY KEY,
    SupplierName TEXT,
    ContactName TEXT,
    Address TEXT,
    City TEXT,
    PostalCode TEXT,
    Country TEXT
)
""")

# %%
cursor.executemany("""

INSERT INTO Suppliers (
    SupplierID,
    SupplierName,
    ContactName,
    Address,
    City,
    PostalCode,
    Country
)
VALUES (?, ?, ?, ?, ?, ?, ?)
""", [
    (1, "Exotic Liquid", "Charlotte Cooper", "49 Gilbert St.", "London", "EC1 4SD", "UK"),
    (2, "New Orleans Cajun Delights", "Shelley Burke", "P.O. Box 78934", "New Orleans", "70117", "USA"),
    (3, "Grandma Kelly's Homestead", "Regina Murphy", "707 Oxford Rd.", "Ann Arbor", "48104", "USA")
])

conn.commit()

# %%
cursor.execute("""
    SELECT Country FROM Customers
    UNION
    SELECT Country FROM Suppliers
    ORDER BY Country;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Germany',)
# ('Mexico',)
# ('Sweden',)
# ('UK',)
# ('USA',)

# %%
cursor.execute("""
    SELECT City, Country FROM Customers
    WHERE Country='Germany'
    UNION
    SELECT City, Country FROM Suppliers
    WHERE Country='Germany'
    ORDER BY City;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Berlin', 'Germany')

# %%
cursor.execute("""
    SELECT 'Customer' AS Type, ContactName, City, Country
    FROM Customers
    UNION
    SELECT 'Supplier', ContactName, City, Country
    FROM Suppliers;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Customer', 'Ana Trujillo', 'México D.F.', 'Mexico')
# ('Customer', 'Antonio Moreno', 'México D.F.', 'Mexico')
# ('Customer', 'Christina Berglund', 'Luleå', 'Sweden')
# ('Customer', 'Maria Anders', 'Berlin', 'Germany')
# ('Customer', 'Thomas Hardy', 'London', 'UK')
# ('Supplier', 'Charlotte Cooper', 'London', 'UK')
# ('Supplier', 'Regina Murphy', 'Ann Arbor', 'USA')
# ('Supplier', 'Shelley Burke', 'New Orleans', 'USA')

# %%
cursor.execute("""
    SELECT Country FROM Customers
    UNION ALL
    SELECT Country FROM Suppliers
    ORDER BY Country;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Germany',)
# ('Mexico',)
# ('Mexico',)
# ('Sweden',)
# ('UK',)
# ('UK',)
# ('USA',)
# ('USA',)

# %%
cursor.execute("""
    SELECT City, Country FROM Customers
    WHERE Country='Germany'
    UNION ALL
    SELECT City, Country FROM Suppliers
    WHERE Country='Germany'
    ORDER BY City;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Berlin', 'Germany')

# %%
cursor.execute("""
    SELECT Country, COUNT(CustomerID) AS [Number of Customers]
    FROM Customers
    GROUP BY Country;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Germany', 1)
# ('Mexico', 2)
# ('Sweden', 1)
# ('UK', 1)

# %%
cursor.execute("""
    SELECT Country, COUNT(CustomerID) AS [Number of Customers]
    FROM Customers
    GROUP BY Country
    ORDER BY COUNT(CustomerID) DESC;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Mexico', 2)
# ('UK', 1)
# ('Sweden', 1)
# ('Germany', 1)

# %%
cursor.execute("""
    SELECT Shippers.ShipperName, COUNT(Orders.OrderID) AS NumberOfOrders
    FROM Orders
    LEFT JOIN Shippers
    ON Orders.ShipperID = Shippers.ShipperID
    GROUP BY ShipperName;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (None, 1)
# ('Federal Shipping', 1)
# ('Speedy Express', 2)
# ('United Package', 1)

# %%
cursor.execute("""
    SELECT Country, COUNT(CustomerID) AS [Number of Customers]
    FROM Customers
    GROUP BY Country
    HAVING COUNT(CustomerID) > 5;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute("""
    SELECT Country, COUNT(CustomerID) AS [Number of Customers]
    FROM Customers
    GROUP BY Country
    HAVING COUNT(CustomerID) > 5
    ORDER BY COUNT(CustomerID) DESC;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute("""
    SELECT Employees.LastName, COUNT(Orders.OrderID) AS NumberOfOrders
    FROM Orders
    INNER JOIN Employees ON Orders.EmployeeID = Employees.EmployeeID
    GROUP BY LastName
    HAVING COUNT(Orders.OrderID) > 10;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute("""
    SELECT Employees.LastName, COUNT(Orders.OrderID) AS NumberOfOrders
    FROM Orders
    INNER JOIN Employees ON Orders.EmployeeID = Employees.EmployeeID
    WHERE LastName = 'Davolio' OR LastName = 'Fuller'
    GROUP BY LastName
    HAVING COUNT(Orders.OrderID) > 25;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute("""
    SELECT SupplierName
    FROM Suppliers
    WHERE EXISTS (
    SELECT ProductName
    FROM Products
    WHERE Products.SupplierID = Suppliers.supplierID AND Price < 10
    );
""")
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute("""
    SELECT SupplierName
    FROM Suppliers
    WHERE EXISTS (
    SELECT ProductName
    FROM Products
    WHERE Products.SupplierID = Suppliers.supplierID AND Price = 22
    );
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('New Orleans Cajun Delights',)

# %%
cursor.execute("""
    SELECT ProductName
    FROM Products
    WHERE ProductID IN (
        SELECT ProductID
        FROM OrderDetails
        WHERE Quantity = 10
    );

""")
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute("""
    SELECT ProductName FROM Products
    WHERE ProductID IN(
    SELECT ProductID
    FROM OrderDetails
    WHERE Quantity > 99
    );
""")
rows = cursor.fetchall()

for row in rows:
    print(row)

# %%
cursor.execute("""
INSERT INTO Customers (CustomerName, City, Country)
SELECT SupplierName, City, Country
FROM Suppliers;

""")
conn.commit()

# %%
cursor.execute("""
INSERT INTO Customers (CustomerName, City, Country)
SELECT SupplierName, City, Country FROM Suppliers
WHERE Country='Germany';

""")

conn.commit()

# %%
cursor.execute("""
SELECT ProductName, Price,
CASE
  WHEN Price < 20 THEN 'Low Cost'
  WHEN Price BETWEEN 20 AND 50 THEN 'Medium Cost'
  ELSE 'High Cost'
END AS PriceCategory
FROM Products;

""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Chais', 18.0, 'Low Cost')
# ('Chang', 19.0, 'Low Cost')
# ('Aniseed Syrup', 10.0, 'Low Cost')
# ("Chef Anton's Cajun Seasoning", 22.0, 'Medium Cost')
# ("Chef Anton's Gumbo Mix", 21.35, 'Medium Cost')

# %%
# remove the Products2 table if it exists
cursor.execute("DROP TABLE IF EXISTS Products2")

cursor.execute("""
CREATE TABLE IF NOT EXISTS Products2 (
    PID INTEGER PRIMARY KEY,
    ProductName TEXT,
    Price REAL,
    InStock INTEGER,
    InOrder INTEGER
)
""")

conn.commit()

# %%
cursor.executemany('''
INSERT OR REPLACE INTO Products2 (PID, ProductName, Price, InStock, InOrder)
VALUES (?, ?, ?, ?, ?)
''', [
    (1, "Jarlsberg", 10.45, 16, 15),
    (2, "Mascarpone", 32.56, 23, None),
    (3, "Gorgonzola", 15.67, 9, 20)
    ])

conn.commit()

# %%
cursor.execute("""
SELECT ProductName, Price * (InStock + COALESCE(InOrder, 0))
FROM Products2;

""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Jarlsberg', 323.95)
# ('Mascarpone', 748.8800000000001)
# ('Gorgonzola', 454.43)

# %%
cursor.execute("""
SELECT ProductName, Price * (InStock + COALESCE(InOrder, 0))
FROM Products2;

""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Jarlsberg', 323.95)
# ('Mascarpone', 748.8800000000001)
# ('Gorgonzola', 454.43)

# %%
cursor.execute("""
SELECT ProductName, Price * (InStock + IFNULL(InOrder, 0))
FROM Products2;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Jarlsberg', 323.95)
# ('Mascarpone', 748.8800000000001)
# ('Gorgonzola', 454.43)

# %%
cursor.execute("""
-- Selects all German customers
SELECT * FROM Customers
WHERE Country = 'Germany';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')

# %%
cursor.execute("""
SELECT * FROM Customers -- WHERE City='Berlin';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')
# (6, 'Exotic Liquid', None, None, 'London', None, 'UK')
# (7, 'New Orleans Cajun Delights', None, None, 'New Orleans', None, 'USA')
# (8, "Grandma Kelly's Homestead", None, None, 'Ann Arbor', None, 'USA')

# %%
cursor.execute("""
-- SELECT * FROM Customers;
SELECT * FROM Products;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Chais', 1, 1, '10 boxes x 20 bags', 18.0)
# (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.0)
# (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.0)
# (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22.0)
# (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35)

# %%
cursor.execute("""
/* Selects all German customers
from Berlin */
SELECT * FROM Customers
WHERE Country = 'Germany' AND City = 'Berlin';
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')

# %%
cursor.execute("""
/* SELECT * FROM Customers;
SELECT * FROM Products;
SELECT * FROM Orders;
SELECT * FROM Categories; */
SELECT * FROM Suppliers;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Exotic Liquid', 'Charlotte Cooper', '49 Gilbert St.', 'London', 'EC1 4SD', 'UK')
# (2, 'New Orleans Cajun Delights', 'Shelley Burke', 'P.O. Box 78934', 'New Orleans', '70117', 'USA')
# (3, "Grandma Kelly's Homestead", 'Regina Murphy', '707 Oxford Rd.', 'Ann Arbor', '48104', 'USA')

# %%
cursor.execute("""
SELECT CustomerName, /*City,*/ Country FROM Customers;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('Alfreds Futterkiste', 'Germany')
# ('Ana Trujillo Emparedados y helados', 'Mexico')
# ('Antonio Moreno Taquería', 'Mexico')
# ('Around the Horn', 'UK')
# ('Berglunds snabbköp', 'Sweden')
# ('Exotic Liquid', 'UK')
# ('New Orleans Cajun Delights', 'USA')
# ("Grandma Kelly's Homestead", 'USA')

# %%
cursor.execute("""
SELECT * FROM Customers WHERE (CustomerName LIKE 'L%'
OR CustomerName LIKE 'R%' /*OR CustomerName LIKE 'S%'
OR CustomerName LIKE 'T%'*/ OR CustomerName LIKE 'W%')
AND Country='USA'
ORDER BY CustomerName;
""")
rows = cursor.fetchall()

for row in rows:
    print(row)
